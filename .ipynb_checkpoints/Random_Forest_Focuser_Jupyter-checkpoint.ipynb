# %%
import pandas as pd
from datetime import datetime 
import pairwise_correlation_miner as pcm

# %%
# Connect to the SQL database and open a cursor
import sqlite3 
conn = sqlite3.connect(r'C:\Users\theor\OneDrive\Desktop\NFL ANALYTICS\NFL_STATS_REFERENCE.db')
cursor = conn.cursor()

#Pull the dataset to mine 
# SQL query to select data
query = "SELECT * FROM ML_GAME_LEVEL_DATA_SET_FAV_VS_UD WHERE SEASON BETWEEN 2002 AND 2021;" 

# Use pandas to read the query result directly into a DataFrame
df_base = pd.read_sql_query(query, conn)

# Display the DataFrame
# List of all column names in the DataFrame
column_names = df_base.columns.tolist()
#print(column_names)

# Print the dataframe (optional)
#print(df_base)


# Format the current time as a string
current_time = datetime.now()
formatted_time = current_time.strftime("%Y-%m-%d %H:%M:%S")
print(f"Step 1 completed: {formatted_time}")
# Out:
# Step 1 completed: 2023-12-29 13:46:35

# %%
# Define the Dataframe
df_to_use = df_base

# Define the target variables to analyze 
target_name = 'RESULT_FAVORITE_TEAM_VICTORY'

# Define the feature variables to analyze 
feature_list = [
'DIV_GAME', 
'TEMPERATURE', 
'WINDSPEED', 
'OUTDOORS', 
'GRASS', 
'WEATHER_RAIN', 
'WEATHER_SNOW', 
'WEATHER_CLEAR', 
'WEATHER_WIND_RANK', 
'WEATHER_TEMPERATURE_RANK', 
'FAVORITE_TEAM_HOME_BINARY', 
'SPREAD_LINE', 
'TOTAL_LINE', 
'FAVORITE_TEAM_REST_DAYS', 
'UNDERDOG_TEAM_REST_DAYS', 
'FAVORITE_TEAM_REST_DAYS_DIFFERENTIAL_ACTUAL', 
'FAVORITE_TEAM_REST_DAYS_DIFFERENTIAL_BUCKET', 
'TREND_DIFF_FAVORITE_OV_VS_UNDERDOG_OV_PLAY_RANK', 
'TREND_DIFF_FAVORITE_OFF_VS_UNDERDOG_DEF_PLAY_RANK', 
'TREND_DIFF_FAVORITE_DEF_VS_UNDERDOG_OFF_PLAY_RANK', 
'TREND_DIFF_UNDERDOG_OV_VS_FAVORITE_OV_PLAY_RANK', 
'TREND_DIFF_UNDERDOG_OFF_VS_FAVORITE_DEF_PLAY_RANK', 
'TREND_DIFF_UNDERDOG_DEF_VS_FAVORITE_OFF_PLAY_RANK', 
'TREND_DIFF_FAVORITE_PASS_OFF_VS_UNDERDOG_PASS_DEF_PLAY_RANK', 
'TREND_DIFF_FAVORITE_RUSH_OFF_VS_UNDERDOG_RUSH_DEF_PLAY_RANK', 
'TREND_DIFF_UNDERDOG_PASS_OFF_VS_FAVORITE_PASS_DEF_PLAY_RANK', 
'TREND_DIFF_UNDERDOG_RUSH_OFF_VS_FAVORITE_RUSH_DEF_PLAY_RANK', 
'TREND_FAVORITE_OVERALL_AVG_PLAY_RANK', 
'TREND_FAVORITE_OVERALL_POSITIVE_PLAY_RATE', 
'TREND_FAVORITE_OVERALL_NEGATIVE_PLAY_RATE', 
'TREND_FAVORITE_OVERALL_POS_TO_NEG_PLAY_RATIO', 
'TREND_FAVORITE_OFFENSE_AVG_PLAY_RANK', 
'TREND_FAVORITE_OFFENSE_POSITIVE_PLAY_RATE', 
'TREND_FAVORITE_OFFENSE_NEGATIVE_PLAY_RATE', 
'TREND_FAVORITE_OFFENSE_POS_TO_NEG_PLAY_RATIO', 
'TREND_FAVORITE_OFFENSE_TOTAL_YARDS_GAINED', 
'TREND_FAVORITE_OFFENSE_YARDS_GAINED_PER_PLAY', 
'TREND_FAVORITE_OFFENSE_TOTAL_TOUCHDOWNS', 
'TREND_FAVORITE_OFFENSE_TOTAL_TOUCHDOWNS_ON_TURNOVERS', 
'TREND_FAVORITE_OFFENSE_PASS_AVG_PLAY_RANK', 
'TREND_FAVORITE_OFFENSE_PASS_POSITIVE_PLAY_RATE', 
'TREND_FAVORITE_OFFENSE_PASS_NEGATIVE_PLAY_RATE', 
'TREND_FAVORITE_OFFENSE_PASS_POS_TO_NEG_PLAY_RATIO', 
'TREND_FAVORITE_OFFENSE_PASS_ATTEMPTS', 
'TREND_FAVORITE_OFFENSE_PASS_COMPLETIONS', 
'TREND_FAVORITE_OFFENSE_PASS_INCOMPLETIONS', 
'TREND_FAVORITE_OFFENSE_PASS_TOUCHDOWNS', 
'TREND_FAVORITE_OFFENSE_PASS_YARDS', 
'TREND_FAVORITE_OFFENSE_PASS_SACKS', 
'TREND_FAVORITE_OFFENSE_PASS_SACKS_PER_ATTEMPT', 
'TREND_FAVORITE_OFFENSE_PASS_QB_HIT', 
'TREND_FAVORITE_OFFENSE_PASS_INTERCEPTIONS', 
'TREND_FAVORITE_OFFENSE_PASS_YARDS_PER_ATTEMPT', 
'TREND_FAVORITE_OFFENSE_PASS_YARDS_PER_COMPLETION', 
'TREND_FAVORITE_OFFENSE_RUSH_AVG_PLAY_RANK', 
'TREND_FAVORITE_OFFENSE_RUSH_POSITIVE_PLAY_RATE', 
'TREND_FAVORITE_OFFENSE_RUSH_NEGATIVE_PLAY_RATE', 
'TREND_FAVORITE_OFFENSE_RUSH_POS_TO_NEG_PLAY_RATIO', 
'TREND_FAVORITE_OFFENSE_RUSH_ATTEMPTS', 
'TREND_FAVORITE_OFFENSE_RUSH_TOUCHDOWNS', 
'TREND_FAVORITE_OFFENSE_RUSH_YARDS', 
'TREND_FAVORITE_OFFENSE_RUSH_YARDS_PER_ATTEMPT', 
'TREND_FAVORITE_KICKING_OFFENSE_PLAY_RANK', 
'TREND_FAVORITE_KICKING_OFFENSE_POSITIVE_PLAY_COUNT', 
'TREND_FAVORITE_KICKING_OFFENSE_NEGATIVE_PLAY_COUNT', 
'TREND_FAVORITE_KICKING_OFFENSE_POS_TO_NEG_PLAY_RATIO', 
'TREND_FAVORITE_KICKING_OFFENSE_FIELD_GOAL_ATTEMPTS_TOTAL', 
'TREND_FAVORITE_KICKING_OFFENSE_FIELD_GOAL_MADE_TOTAL', 
'TREND_FAVORITE_KICKING_OFFENSE_FIELD_GOAL_MAKE_RATE_TOTAL', 
'TREND_FAVORITE_KICKING_OFFENSE_FIELD_GOAL_MISSED_TOTAL', 
'TREND_FAVORITE_KICKING_OFFENSE_FIELD_GOAL_BLOCKED_TOTAL', 
'TREND_FAVORITE_KICKING_OFFENSE_FIELD_GOAL_ATTEMPTS_50', 
'TREND_FAVORITE_KICKING_OFFENSE_FIELD_GOAL_MADE_50', 
'TREND_FAVORITE_KICKING_OFFENSE_FIELD_GOAL_MAKE_RATE_50', 
'TREND_FAVORITE_KICKING_OFFENSE_FIELD_GOAL_ATTEMPTS_40_49', 
'TREND_FAVORITE_KICKING_OFFENSE_FIELD_GOALS_MADE_40_49', 
'TREND_FAVORITE_KICKING_OFFENSE_FIELD_GOAL_MAKE_RATE_40_49', 
'TREND_FAVORITE_KICKING_OFFENSE_FIELD_GOAL_ATTEMPTS_30_39', 
'TREND_FAVORITE_KICKING_OFFENSE_FIELD_GOALS_MADE_30_39', 
'TREND_FAVORITE_KICKING_OFFENSE_FIELD_GOAL_MAKE_RATE_30_39', 
'TREND_FAVORITE_KICKING_OFFENSE_EXTRA_POINT_ATTEMPTS_TOTAL', 
'TREND_FAVORITE_KICKING_OFFENSE_EXTRA_POINT_ATTEMPTS_MADE', 
'TREND_FAVORITE_PUNTING_KICKING_PLAY_RANK', 
'TREND_FAVORITE_PUNTING_KICKING_POSITIVE_PLAY_COUNT', 
'TREND_FAVORITE_PUNTING_KICKING_NEGATIVE_PLAY_COUNT', 
'TREND_FAVORITE_DEFENSE_AVG_PLAY_RANK', 
'TREND_FAVORITE_DEFENSE_POSITIVE_PLAY_RATE', 
'TREND_FAVORITE_DEFENSE_NEGATIVE_PLAY_RATE', 
'TREND_FAVORITE_DEFENSE_POS_TO_NEG_PLAY_RATIO', 
'TREND_FAVORITE_DEFENSE_TOTAL_YARDS_ALLOWED', 
'TREND_FAVORITE_DEFENSE_YARDS_ALLOWED_PER_PLAY', 
'TREND_FAVORITE_DEFENSE_TOTAL_TOUCHDOWNS_ALLOWED', 
'TREND_FAVORITE_DEFENSE_TOTAL_TOUCHDOWNS_SCORED', 
'TREND_FAVORITE_DEFENSE_PASS_AVG_PLAY_RANK', 
'TREND_FAVORITE_DEFENSE_PASS_POSITIVE_PLAY_RATE', 
'TREND_FAVORITE_DEFENSE_PASS_NEGATIVE_PLAY_RATE', 
'TREND_FAVORITE_DEFENSE_PASS_POS_TO_NEG_PLAY_RATIO', 
'TREND_FAVORITE_DEFENSE_PASS_ATTEMPTS', 
'TREND_FAVORITE_DEFENSE_PASS_COMPLETIONS', 
'TREND_FAVORITE_DEFENSE_PASS_INCOMPLETIONS', 
'TREND_FAVORITE_DEFENSE_PASS_TOUCHDOWNS', 
'TREND_FAVORITE_DEFENSE_PASS_YARDS', 
'TREND_FAVORITE_DEFENSE_PASS_SACKS', 
'TREND_FAVORITE_DEFENSE_PASS_SACKS_PER_ATTEMPT', 
'TREND_FAVORITE_DEFENSE_PASS_QB_HIT', 
'TREND_FAVORITE_DEFENSE_PASS_INTERCEPTIONS', 
'TREND_FAVORITE_DEFENSE_PASS_YARDS_PER_ATTEMPT', 
'TREND_FAVORITE_DEFENSE_PASS_YARDS_PER_COMPLETION', 
'TREND_FAVORITE_DEFENSE_RUSH_AVG_PLAY_RANK', 
'TREND_FAVORITE_DEFENSE_RUSH_POSITIVE_PLAY_RATE', 
'TREND_FAVORITE_DEFENSE_RUSH_NEGATIVE_PLAY_RATE', 
'TREND_FAVORITE_DEFENSE_RUSH_POS_TO_NEG_PLAY_RATIO', 
'TREND_FAVORITE_DEFENSE_RUSH_ATTEMPTS', 
'TREND_FAVORITE_DEFENSE_RUSH_TOUCHDOWNS', 
'TREND_FAVORITE_DEFENSE_RUSH_YARDS', 
'TREND_FAVORITE_DEFENSE_RUSH_YARDS_PER_ATTEMPT', 
'TREND_FAVORITE_KICKING_DEFENSE_PLAY_RANK', 
'TREND_FAVORITE_KICKING_DEFENSE_POSITIVE_PLAY_COUNT', 
'TREND_FAVORITE_KICKING_DEFENSE_NEGATIVE_PLAY_COUNT', 
'TREND_FAVORITE_KICKING_DEFENSE_FIELD_GOAL_ATTEMPTS_TOTAL', 
'TREND_FAVORITE_KICKING_DEFENSE_MADE_TOTAL', 
'TREND_FAVORITE_KICKING_DEFENSE_FIELD_GOAL_MAKE_RATE_TOTAL', 
'TREND_FAVORITE_KICKING_DEFENSE_FIELD_GOAL_MISSED_TOTAL', 
'TREND_FAVORITE_KICKING_DEFENSE_FIELD_GOAL_BLOCKED_TOTAL', 
'TREND_FAVORITE_PUNTING_RECEIVING_PLAY_RANK', 
'TREND_FAVORITE_PUNTING_RECEIVING_POSITIVE_PLAY_COUNT', 
'TREND_FAVORITE_PUNTING_RECEIVING_NEGATIVE_PLAY_COUNT', 
'TREND_UNDERDOG_OVERALL_AVG_PLAY_RANK', 
'TREND_UNDERDOG_OVERALL_POSITIVE_PLAY_RATE', 
'TREND_UNDERDOG_OVERALL_NEGATIVE_PLAY_RATE', 
'TREND_UNDERDOG_OVERALL_POS_TO_NEG_PLAY_RATIO', 
'TREND_UNDERDOG_OFFENSE_AVG_PLAY_RANK', 
'TREND_UNDERDOG_OFFENSE_POSITIVE_PLAY_RATE', 
'TREND_UNDERDOG_OFFENSE_NEGATIVE_PLAY_RATE', 
'TREND_UNDERDOG_OFFENSE_POS_TO_NEG_PLAY_RATIO', 
'TREND_UNDERDOG_OFFENSE_TOTAL_YARDS_GAINED', 
'TREND_UNDERDOG_OFFENSE_YARDS_GAINED_PER_PLAY', 
'TREND_UNDERDOG_OFFENSE_TOTAL_TOUCHDOWNS', 
'TREND_UNDERDOG_OFFENSE_TOTAL_TOUCHDOWNS_ON_TURNOVERS', 
'TREND_UNDERDOG_OFFENSE_PASS_AVG_PLAY_RANK', 
'TREND_UNDERDOG_OFFENSE_PASS_POSITIVE_PLAY_RATE', 
'TREND_UNDERDOG_OFFENSE_PASS_NEGATIVE_PLAY_RATE', 
'TREND_UNDERDOG_OFFENSE_PASS_POS_TO_NEG_PLAY_RATIO', 
'TREND_UNDERDOG_OFFENSE_PASS_ATTEMPTS', 
'TREND_UNDERDOG_OFFENSE_PASS_COMPLETIONS', 
'TREND_UNDERDOG_OFFENSE_PASS_INCOMPLETIONS', 
'TREND_UNDERDOG_OFFENSE_PASS_TOUCHDOWNS', 
'TREND_UNDERDOG_OFFENSE_PASS_YARDS', 
'TREND_UNDERDOG_OFFENSE_PASS_SACKS', 
'TREND_UNDERDOG_OFFENSE_PASS_SACKS_PER_ATTEMPT', 
'TREND_UNDERDOG_OFFENSE_PASS_QB_HIT', 
'TREND_UNDERDOG_OFFENSE_PASS_INTERCEPTIONS', 
'TREND_UNDERDOG_OFFENSE_PASS_YARDS_PER_ATTEMPT', 
'TREND_UNDERDOG_OFFENSE_PASS_YARDS_PER_COMPLETION', 
'TREND_UNDERDOG_OFFENSE_RUSH_AVG_PLAY_RANK', 
'TREND_UNDERDOG_OFFENSE_RUSH_POSITIVE_PLAY_RATE', 
'TREND_UNDERDOG_OFFENSE_RUSH_NEGATIVE_PLAY_RATE', 
'TREND_UNDERDOG_OFFENSE_RUSH_POS_TO_NEG_PLAY_RATIO', 
'TREND_UNDERDOG_OFFENSE_RUSH_ATTEMPTS', 
'TREND_UNDERDOG_OFFENSE_RUSH_TOUCHDOWNS', 
'TREND_UNDERDOG_OFFENSE_RUSH_YARDS', 
'TREND_UNDERDOG_OFFENSE_RUSH_YARDS_PER_ATTEMPT', 
'TREND_UNDERDOG_KICKING_OFFENSE_PLAY_RANK', 
'TREND_UNDERDOG_KICKING_OFFENSE_POSITIVE_PLAY_COUNT', 
'TREND_UNDERDOG_KICKING_OFFENSE_NEGATIVE_PLAY_COUNT', 
'TREND_UNDERDOG_KICKING_OFFENSE_POS_TO_NEG_PLAY_RATIO', 
'TREND_UNDERDOG_KICKING_OFFENSE_FIELD_GOAL_ATTEMPTS_TOTAL', 
'TREND_UNDERDOG_KICKING_OFFENSE_FIELD_GOAL_MADE_TOTAL', 
'TREND_UNDERDOG_KICKING_OFFENSE_FIELD_GOAL_MAKE_RATE_TOTAL', 
'TREND_UNDERDOG_KICKING_OFFENSE_FIELD_GOAL_MISSED_TOTAL', 
'TREND_UNDERDOG_KICKING_OFFENSE_FIELD_GOAL_BLOCKED_TOTAL', 
'TREND_UNDERDOG_KICKING_OFFENSE_FIELD_GOAL_ATTEMPTS_50', 
'TREND_UNDERDOG_KICKING_OFFENSE_FIELD_GOAL_MADE_50', 
'TREND_UNDERDOG_KICKING_OFFENSE_FIELD_GOAL_MAKE_RATE_50', 
'TREND_UNDERDOG_KICKING_OFFENSE_FIELD_GOAL_ATTEMPTS_40_49', 
'TREND_UNDERDOG_KICKING_OFFENSE_FIELD_GOALS_MADE_40_49', 
'TREND_UNDERDOG_KICKING_OFFENSE_FIELD_GOAL_MAKE_RATE_40_49', 
'TREND_UNDERDOG_KICKING_OFFENSE_FIELD_GOAL_ATTEMPTS_30_39', 
'TREND_UNDERDOG_KICKING_OFFENSE_FIELD_GOALS_MADE_30_39', 
'TREND_UNDERDOG_KICKING_OFFENSE_FIELD_GOAL_MAKE_RATE_30_39', 
'TREND_UNDERDOG_KICKING_OFFENSE_EXTRA_POINT_ATTEMPTS_TOTAL', 
'TREND_UNDERDOG_KICKING_OFFENSE_EXTRA_POINT_ATTEMPTS_MADE', 
'TREND_UNDERDOG_PUNTING_KICKING_PLAY_RANK', 
'TREND_UNDERDOG_PUNTING_KICKING_POSITIVE_PLAY_COUNT', 
'TREND_UNDERDOG_PUNTING_KICKING_NEGATIVE_PLAY_COUNT', 
'TREND_UNDERDOG_DEFENSE_AVG_PLAY_RANK', 
'TREND_UNDERDOG_DEFENSE_POSITIVE_PLAY_RATE', 
'TREND_UNDERDOG_DEFENSE_NEGATIVE_PLAY_RATE', 
'TREND_UNDERDOG_DEFENSE_POS_TO_NEG_PLAY_RATIO', 
'TREND_UNDERDOG_DEFENSE_TOTAL_YARDS_ALLOWED', 
'TREND_UNDERDOG_DEFENSE_YARDS_ALLOWED_PER_PLAY', 
'TREND_UNDERDOG_DEFENSE_TOTAL_TOUCHDOWNS_ALLOWED', 
'TREND_UNDERDOG_DEFENSE_TOTAL_TOUCHDOWNS_SCORED', 
'TREND_UNDERDOG_DEFENSE_PASS_AVG_PLAY_RANK', 
'TREND_UNDERDOG_DEFENSE_PASS_POSITIVE_PLAY_RATE', 
'TREND_UNDERDOG_DEFENSE_PASS_NEGATIVE_PLAY_RATE', 
'TREND_UNDERDOG_DEFENSE_PASS_POS_TO_NEG_PLAY_RATIO', 
'TREND_UNDERDOG_DEFENSE_PASS_ATTEMPTS', 
'TREND_UNDERDOG_DEFENSE_PASS_COMPLETIONS', 
'TREND_UNDERDOG_DEFENSE_PASS_INCOMPLETIONS', 
'TREND_UNDERDOG_DEFENSE_PASS_TOUCHDOWNS', 
'TREND_UNDERDOG_DEFENSE_PASS_YARDS', 
'TREND_UNDERDOG_DEFENSE_PASS_SACKS', 
'TREND_UNDERDOG_DEFENSE_PASS_SACKS_PER_ATTEMPT', 
'TREND_UNDERDOG_DEFENSE_PASS_QB_HIT', 
'TREND_UNDERDOG_DEFENSE_PASS_INTERCEPTIONS', 
'TREND_UNDERDOG_DEFENSE_PASS_YARDS_PER_ATTEMPT', 
'TREND_UNDERDOG_DEFENSE_PASS_YARDS_PER_COMPLETION', 
'TREND_UNDERDOG_DEFENSE_RUSH_AVG_PLAY_RANK', 
'TREND_UNDERDOG_DEFENSE_RUSH_POSITIVE_PLAY_RATE', 
'TREND_UNDERDOG_DEFENSE_RUSH_NEGATIVE_PLAY_RATE', 
'TREND_UNDERDOG_DEFENSE_RUSH_POS_TO_NEG_PLAY_RATIO', 
'TREND_UNDERDOG_DEFENSE_RUSH_ATTEMPTS', 
'TREND_UNDERDOG_DEFENSE_RUSH_TOUCHDOWNS', 
'TREND_UNDERDOG_DEFENSE_RUSH_YARDS', 
'TREND_UNDERDOG_DEFENSE_RUSH_YARDS_PER_ATTEMPT', 
'TREND_UNDERDOG_KICKING_DEFENSE_PLAY_RANK', 
'TREND_UNDERDOG_KICKING_DEFENSE_POSITIVE_PLAY_COUNT', 
'TREND_UNDERDOG_KICKING_DEFENSE_NEGATIVE_PLAY_COUNT', 
'TREND_UNDERDOG_KICKING_DEFENSE_FIELD_GOAL_ATTEMPTS_TOTAL', 
'TREND_UNDERDOG_KICKING_DEFENSE_MADE_TOTAL', 
'TREND_UNDERDOG_KICKING_DEFENSE_FIELD_GOAL_MAKE_RATE_TOTAL', 
'TREND_UNDERDOG_KICKING_DEFENSE_FIELD_GOAL_MISSED_TOTAL', 
'TREND_UNDERDOG_KICKING_DEFENSE_FIELD_GOAL_BLOCKED_TOTAL', 
'TREND_UNDERDOG_PUNTING_RECEIVING_PLAY_RANK', 
'TREND_UNDERDOG_PUNTING_RECEIVING_POSITIVE_PLAY_COUNT', 
'TREND_UNDERDOG_PUNTING_RECEIVING_NEGATIVE_PLAY_COUNT' 
]

# Specify the file path where you want to save the CSV file
export_file_path_string = r"C:\Users\theor\Python Scripts\NFL\Analysis_Results\favorite_team_victory.csv"
